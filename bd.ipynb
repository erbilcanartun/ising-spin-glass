# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import mpmath as mp
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from renormalization import *

# %%
method = 'bd'

# %% [markdown]
# ## Single search for a critical point

# %%
T = 30 # The system is certainly in disordered phase for T = 30
p = 0.5
N =  500
mp.mp.dps = 20 # Set the precision of mpmath to 20 decimal places
critical_point(T, p, N, 0.001, "vertical", method)
# Out:
# Initial search:
# Thigh = 30
# Thigh = 29
# Thigh = 28
# Thigh = 27
# Thigh = 26
# Thigh = 25
# Thigh = 24
# Thigh = 23
# Thigh = 22
# Thigh = 21
# Thigh = 20
# Thigh = 19
# Thigh = 18
# Thigh = 17
# Thigh = 16
# Thigh = 15
# Thigh = 14
# Thigh = 13
# Thigh = 12
# Thigh = 11
# Thigh = 10
# Thigh = 9
# Thigh = 8
# Thigh = 7
# Thigh = 6
# Thigh = 5
# Thigh = 4
# Thigh = 3
# Tlow = 2
#
# Tlow = 2, Tmid = 2.5, Thigh = 3 | e = 1
# Tlow = 2, Tmid = 2.25, Thigh = 2.5 | e = 0.5
# Tlow = 2, Tmid = 2.125, Thigh = 2.25 | e = 0.25
# phase: not disorder!
# Tlow = 2.125, Tmid = 2.1875, Thigh = 2.25 | e = 0.125
# Tlow = 2.125, Tmid = 2.1562, Thigh = 2.1875 | e = 0.0625
# Tlow = 2.125, Tmid = 2.1406, Thigh = 2.1562 | e = 0.0312
# Tlow = 2.125, Tmid = 2.1328, Thigh = 2.1406 | e = 0.0156
# Tlow = 2.125, Tmid = 2.1289, Thigh = 2.1328 | e = 0.0078
# Tlow = 2.125, Tmid = 2.127, Thigh = 2.1289 | e = 0.0039
# phase: not disorder!
# Tlow = 2.127, Tmid = 2.1279, Thigh = 2.1289 | e = 0.002
# phase: not disorder!
# Tlow = 2.1279, Tmid = 2.1279, Thigh = 2.1289 | e = 0.001
#
# Critical point = 2.12841796875
# 2.12841796875

# %% [markdown]
# # Phase boundary by multiple searches

# %% [markdown]
# ## Horizontal phase boundary

# %% [markdown]
# ### Prepare p values to search for

# %%
# Method 1: Equally spaced p values
p_values = np.linspace(0, 0.5, 20)

# %%
# Method 2: Non-equally spaced p values (more points near the radically changing slope)
# This is done to avoid unnecessary calculations in regions where the slope is almost constant
pi = 0
p_values = [pi]    

Np = 3
for i in range(Np):
    pi = pi + 0.34 / Np
    p_values.append(round(pi, 5))
    
Np = 7
for i in range(Np):
    pi = pi + 0.1 / Np
    p_values.append(round(pi, 5))

Np = 3
for i in range(Np):
    pi = pi + 0.06 / Np
    p_values.append(round(pi, 5))

# %% [markdown]
# ### Calculation of the horizontal phase boundary

# %%
Tc = 30
N = 500
mp.mp.dps = 20

para_boundary = []
for i, p in enumerate(p_values):

    Ti = Tc + 1
    Tc = critical_point(Ti, p, N, 0.001, "vertical", method)
    para_boundary.append([p, 1-p, Tc])
    print("\n======================================================\n")
# Out:
# Initial search:
# Thigh = 31
# Thigh = 30
# Thigh = 29
# Thigh = 28
# Thigh = 27
# Thigh = 26
# Tlow = 25
#
# Tlow = 25, Tmid = 25.5, Thigh = 26 | e = 1
# Tlow = 25, Tmid = 25.25, Thigh = 25.5 | e = 0.5
# phase: not disorder!
# Tlow = 25.25, Tmid = 25.375, Thigh = 25.5 | e = 0.25
# phase: not disorder!
# Tlow = 25.375, Tmid = 25.4375, Thigh = 25.5 | e = 0.125
# Tlow = 25.375, Tmid = 25.4062, Thigh = 25.4375 | e = 0.0625
# phase: not disorder!
# Tlow = 25.4062, Tmid = 25.4219, Thigh = 25.4375 | e = 0.0312
# Tlow = 25.4062, Tmid = 25.4141, Thigh = 25.4219 | e = 0.0156
# Tlow = 25.4062, Tmid = 25.4102, Thigh = 25.4141 | e = 0.0078
# Tlow = 25.4062, Tmid = 25.4082, Thigh = 25.4102 | e = 0.0039
# phase: not disorder!
# Tlow = 25.4082, Tmid = 25.4092, Thigh = 25.4102 | e = 0.002
# phase: not disorder!
# Tlow = 25.4092, Tmid = 25.4092, Thigh = 25.4102 | e = 0.001
#
# Critical point = 25.40966796875
#
# ======================================================
#
# Initial search:
# Thigh = 26.40966796875
# Thigh = 25.40966796875
# Thigh = 24.40966796875
# Tlow = 23.40966796875
#
# Tlow = 23.4097, Tmid = 23.9097, Thigh = 24.4097 | e = 1.0
# phase: not disorder!
# Tlow = 23.9097, Tmid = 24.1597, Thigh = 24.4097 | e = 0.5
# phase: not disorder!
# Tlow = 24.1597, Tmid = 24.2847, Thigh = 24.4097 | e = 0.25
# Tlow = 24.1597, Tmid = 24.2222, Thigh = 24.2847 | e = 0.125
# Tlow = 24.1597, Tmid = 24.1909, Thigh = 24.2222 | e = 0.0625
# phase: not disorder!
# Tlow = 24.1909, Tmid = 24.2065, Thigh = 24.2222 | e = 0.0312
# Tlow = 24.1909, Tmid = 24.1987, Thigh = 24.2065 | e = 0.0156
# phase: not disorder!
# Tlow = 24.1987, Tmid = 24.2026, Thigh = 24.2065 | e = 0.0078
# phase: not disorder!
# Tlow = 24.2026, Tmid = 24.2046, Thigh = 24.2065 | e = 0.0039
# Tlow = 24.2026, Tmid = 24.2036, Thigh = 24.2046 | e = 0.002
# phase: not disorder!
# Tlow = 24.2036, Tmid = 24.2036, Thigh = 24.2046 | e = 0.001
#
# Critical point = 24.2041015625
#
# ======================================================
#
# Initial search:
# Thigh = 25.2041015625
# Thigh = 24.2041015625
# Thigh = 23.2041015625
# Tlow = 22.2041015625
#
# Tlow = 22.2041, Tmid = 22.7041, Thigh = 23.2041 | e = 1.0
# phase: not disorder!
# Tlow = 22.7041, Tmid = 22.9541, Thigh = 23.2041 | e = 0.5
# Tlow = 22.7041, Tmid = 22.8291, Thigh = 22.9541 | e = 0.25
# Tlow = 22.7041, Tmid = 22.7666, Thigh = 22.8291 | e = 0.125
# phase: not disorder!
# Tlow = 22.7666, Tmid = 22.7979, Thigh = 22.8291 | e = 0.0625
# Tlow = 22.7666, Tmid = 22.7822, Thigh = 22.7979 | e = 0.0312
# Tlow = 22.7666, Tmid = 22.7744, Thigh = 22.7822 | e = 0.0156
# Tlow = 22.7666, Tmid = 22.7705, Thigh = 22.7744 | e = 0.0078
# phase: not disorder!
# Tlow = 22.7705, Tmid = 22.7725, Thigh = 22.7744 | e = 0.0039
# phase: not disorder!
# Tlow = 22.7725, Tmid = 22.7734, Thigh = 22.7744 | e = 0.002
# Tlow = 22.7725, Tmid = 22.7734, Thigh = 22.7734 | e = 0.001
#
# Critical point = 22.77294921875
#
# ======================================================
#
# Initial search:
# Thigh = 23.77294921875
# Thigh = 22.77294921875
# Thigh = 21.77294921875
# Tlow = 20.77294921875
#
# Tlow = 20.7729, Tmid = 21.2729, Thigh = 21.7729 | e = 1.0
# phase: not disorder!
# Tlow = 21.2729, Tmid = 21.5229, Thigh = 21.7729 | e = 0.5
# Tlow = 21.2729, Tmid = 21.3979, Thigh = 21.5229 | e = 0.25
# phase: not disorder!
# Tlow = 21.3979, Tmid = 21.4604, Thigh = 21.5229 | e = 0.125
# Tlow = 21.3979, Tmid = 21.4292, Thigh = 21.4604 | e = 0.0625
# Tlow = 21.3979, Tmid = 21.4136, Thigh = 21.4292 | e = 0.0312
# phase: not disorder!
# Tlow = 21.4136, Tmid = 21.4214, Thigh = 21.4292 | e = 0.0156
# phase: not disorder!
# Tlow = 21.4214, Tmid = 21.4253, Thigh = 21.4292 | e = 0.0078
# Tlow = 21.4214, Tmid = 21.4233, Thigh = 21.4253 | e = 0.0039
# phase: not disorder!
# Tlow = 21.4233, Tmid = 21.4243, Thigh = 21.4253 | e = 0.002
# phase: not disorder!
# Tlow = 21.4243, Tmid = 21.4243, Thigh = 21.4253 | e = 0.001
#
# Critical point = 21.4248046875
#
# ======================================================
#
# Initial search:
# Thigh = 22.4248046875
# Thigh = 21.4248046875
# Thigh = 20.4248046875
# Tlow = 19.4248046875
#
# Tlow = 19.4248, Tmid = 19.9248, Thigh = 20.4248 | e = 1.0
# Tlow = 19.4248, Tmid = 19.6748, Thigh = 19.9248 | e = 0.5
# phase: not disorder!
# Tlow = 19.6748, Tmid = 19.7998, Thigh = 19.9248 | e = 0.25
# phase: not disorder!
# Tlow = 19.7998, Tmid = 19.8623, Thigh = 19.9248 | e = 0.125
# phase: not disorder!
# Tlow = 19.8623, Tmid = 19.8936, Thigh = 19.9248 | e = 0.0625
# phase: not disorder!
# Tlow = 19.8936, Tmid = 19.9092, Thigh = 19.9248 | e = 0.0312
# phase: not disorder!
# Tlow = 19.9092, Tmid = 19.917, Thigh = 19.9248 | e = 0.0156
# Tlow = 19.9092, Tmid = 19.9131, Thigh = 19.917 | e = 0.0078
# phase: not disorder!
# Tlow = 19.9131, Tmid = 19.915, Thigh = 19.917 | e = 0.0039
# phase: not disorder!
# Tlow = 19.915, Tmid = 19.916, Thigh = 19.917 | e = 0.002
# Tlow = 19.915, Tmid = 19.916, Thigh = 19.916 | e = 0.001
#
# Critical point = 19.91552734375
#
# ======================================================
#
# Initial search:
# Thigh = 20.91552734375
# Thigh = 19.91552734375
# Thigh = 18.91552734375
# Tlow = 17.91552734375
#
# Tlow = 17.9155, Tmid = 18.4155, Thigh = 18.9155 | e = 1.0
# phase: not disorder!
# Tlow = 18.4155, Tmid = 18.6655, Thigh = 18.9155 | e = 0.5
# Tlow = 18.4155, Tmid = 18.5405, Thigh = 18.6655 | e = 0.25
# Tlow = 18.4155, Tmid = 18.478, Thigh = 18.5405 | e = 0.125
# phase: not disorder!
# Tlow = 18.478, Tmid = 18.5093, Thigh = 18.5405 | e = 0.0625
# phase: not disorder!
# Tlow = 18.5093, Tmid = 18.5249, Thigh = 18.5405 | e = 0.0312
# Tlow = 18.5093, Tmid = 18.5171, Thigh = 18.5249 | e = 0.0156
# phase: not disorder!
# Tlow = 18.5171, Tmid = 18.521, Thigh = 18.5249 | e = 0.0078
# phase: not disorder!
# Tlow = 18.521, Tmid = 18.5229, Thigh = 18.5249 | e = 0.0039
# Tlow = 18.521, Tmid = 18.522, Thigh = 18.5229 | e = 0.002
# phase: not disorder!
# Tlow = 18.522, Tmid = 18.522, Thigh = 18.5229 | e = 0.001
#
# Critical point = 18.5224609375
#
# ======================================================
#
# Initial search:
# Thigh = 19.5224609375
# Thigh = 18.5224609375
# Thigh = 17.5224609375
# Tlow = 16.5224609375
#
# Tlow = 16.5225, Tmid = 17.0225, Thigh = 17.5225 | e = 1.0
# phase: not disorder!
# Tlow = 17.0225, Tmid = 17.2725, Thigh = 17.5225 | e = 0.5
# Tlow = 17.0225, Tmid = 17.1475, Thigh = 17.2725 | e = 0.25
# Tlow = 17.0225, Tmid = 17.085, Thigh = 17.1475 | e = 0.125
# Tlow = 17.0225, Tmid = 17.0537, Thigh = 17.085 | e = 0.0625
# Tlow = 17.0225, Tmid = 17.0381, Thigh = 17.0537 | e = 0.0312
# phase: not disorder!
# Tlow = 17.0381, Tmid = 17.0459, Thigh = 17.0537 | e = 0.0156
# phase: not disorder!
# Tlow = 17.0459, Tmid = 17.0498, Thigh = 17.0537 | e = 0.0078
# phase: not disorder!
# Tlow = 17.0498, Tmid = 17.0518, Thigh = 17.0537 | e = 0.0039
# phase: not disorder!
# Tlow = 17.0518, Tmid = 17.0527, Thigh = 17.0537 | e = 0.002
# Tlow = 17.0518, Tmid = 17.0527, Thigh = 17.0527 | e = 0.001
#
# Critical point = 17.05224609375
#
# ======================================================
#
# Initial search:
# Thigh = 18.05224609375
# Thigh = 17.05224609375
# Thigh = 16.05224609375
# Tlow = 15.05224609375
#
# Tlow = 15.0522, Tmid = 15.5522, Thigh = 16.0522 | e = 1.0
# Tlow = 15.0522, Tmid = 15.3022, Thigh = 15.5522 | e = 0.5
# phase: not disorder!
# Tlow = 15.3022, Tmid = 15.4272, Thigh = 15.5522 | e = 0.25
# phase: not disorder!
# Tlow = 15.4272, Tmid = 15.4897, Thigh = 15.5522 | e = 0.125
# Tlow = 15.4272, Tmid = 15.4585, Thigh = 15.4897 | e = 0.0625
# phase: not disorder!
# Tlow = 15.4585, Tmid = 15.4741, Thigh = 15.4897 | e = 0.0312
# phase: not disorder!
# Tlow = 15.4741, Tmid = 15.4819, Thigh = 15.4897 | e = 0.0156
# phase: not disorder!
# Tlow = 15.4819, Tmid = 15.4858, Thigh = 15.4897 | e = 0.0078
# Tlow = 15.4819, Tmid = 15.4839, Thigh = 15.4858 | e = 0.0039
# Tlow = 15.4819, Tmid = 15.4829, Thigh = 15.4839 | e = 0.002
# Tlow = 15.4819, Tmid = 15.4829, Thigh = 15.4829 | e = 0.001
#
# Critical point = 15.482421875
#
# ======================================================
#
# Initial search:
# Thigh = 16.482421875
# Thigh = 15.482421875
# Thigh = 14.482421875
# Tlow = 13.482421875
#
# Tlow = 13.4824, Tmid = 13.9824, Thigh = 14.4824 | e = 1.0
# phase: not disorder!
# Tlow = 13.9824, Tmid = 14.2324, Thigh = 14.4824 | e = 0.5
# Tlow = 13.9824, Tmid = 14.1074, Thigh = 14.2324 | e = 0.25
# phase: not disorder!
# Tlow = 14.1074, Tmid = 14.1699, Thigh = 14.2324 | e = 0.125
# Tlow = 14.1074, Tmid = 14.1387, Thigh = 14.1699 | e = 0.0625
# phase: not disorder!
# Tlow = 14.1387, Tmid = 14.1543, Thigh = 14.1699 | e = 0.0312
# phase: not disorder!
# Tlow = 14.1543, Tmid = 14.1621, Thigh = 14.1699 | e = 0.0156
# Tlow = 14.1543, Tmid = 14.1582, Thigh = 14.1621 | e = 0.0078
# Tlow = 14.1543, Tmid = 14.1562, Thigh = 14.1582 | e = 0.0039
# Tlow = 14.1543, Tmid = 14.1553, Thigh = 14.1562 | e = 0.002
# phase: not disorder!
# Tlow = 14.1553, Tmid = 14.1553, Thigh = 14.1562 | e = 0.001
#
# Critical point = 14.15576171875
#
# ======================================================
#
# Initial search:
# Thigh = 15.15576171875
# Thigh = 14.15576171875
# Thigh = 13.15576171875
# Tlow = 12.15576171875
#
# Tlow = 12.1558, Tmid = 12.6558, Thigh = 13.1558 | e = 1.0
# phase: not disorder!
# Tlow = 12.6558, Tmid = 12.9058, Thigh = 13.1558 | e = 0.5
# Tlow = 12.6558, Tmid = 12.7808, Thigh = 12.9058 | e = 0.25
# Tlow = 12.6558, Tmid = 12.7183, Thigh = 12.7808 | e = 0.125
# Tlow = 12.6558, Tmid = 12.687, Thigh = 12.7183 | e = 0.0625
# Tlow = 12.6558, Tmid = 12.6714, Thigh = 12.687 | e = 0.0312
# phase: not disorder!
# Tlow = 12.6714, Tmid = 12.6792, Thigh = 12.687 | e = 0.0156
# phase: not disorder!
# Tlow = 12.6792, Tmid = 12.6831, Thigh = 12.687 | e = 0.0078
# phase: not disorder!
# Tlow = 12.6831, Tmid = 12.6851, Thigh = 12.687 | e = 0.0039
# Tlow = 12.6831, Tmid = 12.6841, Thigh = 12.6851 | e = 0.002
# phase: not disorder!
# Tlow = 12.6841, Tmid = 12.6841, Thigh = 12.6851 | e = 0.001
#
# Critical point = 12.6845703125
#
# ======================================================
#
# Initial search:
# Thigh = 13.6845703125
# Thigh = 12.6845703125
# Thigh = 11.6845703125
# Tlow = 10.6845703125
#
# Tlow = 10.6846, Tmid = 11.1846, Thigh = 11.6846 | e = 1.0
# phase: not disorder!
# Tlow = 11.1846, Tmid = 11.4346, Thigh = 11.6846 | e = 0.5
# Tlow = 11.1846, Tmid = 11.3096, Thigh = 11.4346 | e = 0.25
# Tlow = 11.1846, Tmid = 11.2471, Thigh = 11.3096 | e = 0.125
# Tlow = 11.1846, Tmid = 11.2158, Thigh = 11.2471 | e = 0.0625
# phase: not disorder!
# Tlow = 11.2158, Tmid = 11.2314, Thigh = 11.2471 | e = 0.0312
# phase: not disorder!
# Tlow = 11.2314, Tmid = 11.2393, Thigh = 11.2471 | e = 0.0156
# phase: not disorder!
# Tlow = 11.2393, Tmid = 11.2432, Thigh = 11.2471 | e = 0.0078
# Tlow = 11.2393, Tmid = 11.2412, Thigh = 11.2432 | e = 0.0039
# phase: not disorder!
# Tlow = 11.2412, Tmid = 11.2422, Thigh = 11.2432 | e = 0.002
# Tlow = 11.2412, Tmid = 11.2422, Thigh = 11.2422 | e = 0.001
#
# Critical point = 11.24169921875
#
# ======================================================
#
# Initial search:
# Thigh = 12.24169921875
# Thigh = 11.24169921875
# Thigh = 10.24169921875
# Tlow = 9.24169921875
#
# Tlow = 9.2417, Tmid = 9.7417, Thigh = 10.2417 | e = 1.0
# Tlow = 9.2417, Tmid = 9.4917, Thigh = 9.7417 | e = 0.5
# phase: not disorder!
# Tlow = 9.4917, Tmid = 9.6167, Thigh = 9.7417 | e = 0.25
# Tlow = 9.4917, Tmid = 9.5542, Thigh = 9.6167 | e = 0.125
# Tlow = 9.4917, Tmid = 9.5229, Thigh = 9.5542 | e = 0.0625
# Tlow = 9.4917, Tmid = 9.5073, Thigh = 9.5229 | e = 0.0312
# phase: not disorder!
# Tlow = 9.5073, Tmid = 9.5151, Thigh = 9.5229 | e = 0.0156
# phase: not disorder!
# Tlow = 9.5151, Tmid = 9.519, Thigh = 9.5229 | e = 0.0078
# Tlow = 9.5151, Tmid = 9.5171, Thigh = 9.519 | e = 0.0039
# phase: not disorder!
# Tlow = 9.5171, Tmid = 9.5181, Thigh = 9.519 | e = 0.002
# Tlow = 9.5171, Tmid = 9.5181, Thigh = 9.5181 | e = 0.001
#
# Critical point = 9.517578125
#
# ======================================================
#
# Initial search:
# Thigh = 10.517578125
# Thigh = 9.517578125
# Thigh = 8.517578125
# Tlow = 7.517578125
#
# Tlow = 7.5176, Tmid = 8.0176, Thigh = 8.5176 | e = 1.0
# phase: not disorder!
# Tlow = 8.0176, Tmid = 8.2676, Thigh = 8.5176 | e = 0.5
# Tlow = 8.0176, Tmid = 8.1426, Thigh = 8.2676 | e = 0.25
# phase: not disorder!
# Tlow = 8.1426, Tmid = 8.2051, Thigh = 8.2676 | e = 0.125
# Tlow = 8.1426, Tmid = 8.1738, Thigh = 8.2051 | e = 0.0625
# phase: not disorder!
# Tlow = 8.1738, Tmid = 8.1895, Thigh = 8.2051 | e = 0.0312
# Tlow = 8.1738, Tmid = 8.1816, Thigh = 8.1895 | e = 0.0156
# Tlow = 8.1738, Tmid = 8.1777, Thigh = 8.1816 | e = 0.0078
# Tlow = 8.1738, Tmid = 8.1758, Thigh = 8.1777 | e = 0.0039
# Tlow = 8.1738, Tmid = 8.1748, Thigh = 8.1758 | e = 0.002
# phase: not disorder!
# Tlow = 8.1748, Tmid = 8.1748, Thigh = 8.1758 | e = 0.001
#
# Critical point = 8.17529296875
#
# ======================================================
#
# Initial search:
# Thigh = 9.17529296875
# Thigh = 8.17529296875
# Thigh = 7.17529296875
# Tlow = 6.17529296875
#
# Tlow = 6.1753, Tmid = 6.6753, Thigh = 7.1753 | e = 1.0
# Tlow = 6.1753, Tmid = 6.4253, Thigh = 6.6753 | e = 0.5
# Tlow = 6.1753, Tmid = 6.3003, Thigh = 6.4253 | e = 0.25
# Tlow = 6.1753, Tmid = 6.2378, Thigh = 6.3003 | e = 0.125
# Tlow = 6.1753, Tmid = 6.2065, Thigh = 6.2378 | e = 0.0625
# Tlow = 6.1753, Tmid = 6.1909, Thigh = 6.2065 | e = 0.0312
# Tlow = 6.1753, Tmid = 6.1831, Thigh = 6.1909 | e = 0.0156
# phase: not disorder!
# Tlow = 6.1831, Tmid = 6.187, Thigh = 6.1909 | e = 0.0078
# Tlow = 6.1831, Tmid = 6.1851, Thigh = 6.187 | e = 0.0039
# phase: not disorder!
# Tlow = 6.1851, Tmid = 6.186, Thigh = 6.187 | e = 0.002
# phase: not disorder!
# Tlow = 6.186, Tmid = 6.186, Thigh = 6.187 | e = 0.001
#
# Critical point = 6.1865234375
#
# ======================================================
#
# Initial search:
# Thigh = 7.1865234375
# Thigh = 6.1865234375
# Thigh = 5.1865234375
# Tlow = 4.1865234375
#
# Tlow = 4.1865, Tmid = 4.6865, Thigh = 5.1865 | e = 1.0
# Tlow = 4.1865, Tmid = 4.4365, Thigh = 4.6865 | e = 0.5
# Tlow = 4.1865, Tmid = 4.3115, Thigh = 4.4365 | e = 0.25
# phase: not disorder!
# Tlow = 4.3115, Tmid = 4.374, Thigh = 4.4365 | e = 0.125
# phase: not disorder!
# Tlow = 4.374, Tmid = 4.4053, Thigh = 4.4365 | e = 0.0625
# Tlow = 4.374, Tmid = 4.3896, Thigh = 4.4053 | e = 0.0312
# phase: not disorder!
# Tlow = 4.3896, Tmid = 4.3975, Thigh = 4.4053 | e = 0.0156
# Tlow = 4.3896, Tmid = 4.3936, Thigh = 4.3975 | e = 0.0078
# Tlow = 4.3896, Tmid = 4.3916, Thigh = 4.3936 | e = 0.0039
# phase: not disorder!
# Tlow = 4.3916, Tmid = 4.3926, Thigh = 4.3936 | e = 0.002
# phase: not disorder!
# Tlow = 4.3926, Tmid = 4.3926, Thigh = 4.3936 | e = 0.001
#
# Critical point = 4.39306640625
#
# ======================================================
#
# Initial search:
# Thigh = 5.39306640625
# Thigh = 4.39306640625
# Thigh = 3.39306640625
# Tlow = 2.39306640625
#
# Tlow = 2.3931, Tmid = 2.8931, Thigh = 3.3931 | e = 1.0
# Tlow = 2.3931, Tmid = 2.6431, Thigh = 2.8931 | e = 0.5
# phase: not disorder!
# Tlow = 2.6431, Tmid = 2.7681, Thigh = 2.8931 | e = 0.25
# phase: not disorder!
# Tlow = 2.7681, Tmid = 2.8306, Thigh = 2.8931 | e = 0.125
# phase: not disorder!
# Tlow = 2.8306, Tmid = 2.8618, Thigh = 2.8931 | e = 0.0625
# Tlow = 2.8306, Tmid = 2.8462, Thigh = 2.8618 | e = 0.0312
# Tlow = 2.8306, Tmid = 2.8384, Thigh = 2.8462 | e = 0.0156
# Tlow = 2.8306, Tmid = 2.8345, Thigh = 2.8384 | e = 0.0078
# Tlow = 2.8306, Tmid = 2.8325, Thigh = 2.8345 | e = 0.0039
# phase: not disorder!
# Tlow = 2.8325, Tmid = 2.8335, Thigh = 2.8345 | e = 0.002
# Tlow = 2.8325, Tmid = 2.8335, Thigh = 2.8335 | e = 0.001
#
# Critical point = 2.8330078125
#
# ======================================================
#
# Initial search:
# Thigh = 3.8330078125
# Thigh = 2.8330078125
# Tlow = 1.8330078125
#
# Tlow = 1.833, Tmid = 2.333, Thigh = 2.833 | e = 1.0
# Tlow = 1.833, Tmid = 2.083, Thigh = 2.333 | e = 0.5
# phase: not disorder!
# Tlow = 2.083, Tmid = 2.208, Thigh = 2.333 | e = 0.25
# phase: not disorder!
# Tlow = 2.208, Tmid = 2.2705, Thigh = 2.333 | e = 0.125
# phase: not disorder!
# Tlow = 2.2705, Tmid = 2.3018, Thigh = 2.333 | e = 0.0625
# phase: not disorder!
# Tlow = 2.3018, Tmid = 2.3174, Thigh = 2.333 | e = 0.0312
# Tlow = 2.3018, Tmid = 2.3096, Thigh = 2.3174 | e = 0.0156
# Tlow = 2.3018, Tmid = 2.3057, Thigh = 2.3096 | e = 0.0078
# Tlow = 2.3018, Tmid = 2.3037, Thigh = 2.3057 | e = 0.0039
# Tlow = 2.3018, Tmid = 2.3027, Thigh = 2.3037 | e = 0.002
# phase: not disorder!
# Tlow = 2.3027, Tmid = 2.3027, Thigh = 2.3037 | e = 0.001
#
# Critical point = 2.30322265625
#
# ======================================================
#
# Initial search:
# Thigh = 3.30322265625
# Thigh = 2.30322265625
# Tlow = 1.30322265625
#
# Tlow = 1.3032, Tmid = 1.8032, Thigh = 2.3032 | e = 1.0
# phase: not disorder!
# Tlow = 1.8032, Tmid = 2.0532, Thigh = 2.3032 | e = 0.5
# phase: not disorder!
# Tlow = 2.0532, Tmid = 2.1782, Thigh = 2.3032 | e = 0.25
# phase: not disorder!
# Tlow = 2.1782, Tmid = 2.2407, Thigh = 2.3032 | e = 0.125
# phase: not disorder!
# Tlow = 2.2407, Tmid = 2.272, Thigh = 2.3032 | e = 0.0625
# Tlow = 2.2407, Tmid = 2.2563, Thigh = 2.272 | e = 0.0312
# Tlow = 2.2407, Tmid = 2.2485, Thigh = 2.2563 | e = 0.0156
# Tlow = 2.2407, Tmid = 2.2446, Thigh = 2.2485 | e = 0.0078
# Tlow = 2.2407, Tmid = 2.2427, Thigh = 2.2446 | e = 0.0039
# phase: not disorder!
# Tlow = 2.2427, Tmid = 2.2437, Thigh = 2.2446 | e = 0.002
# Tlow = 2.2427, Tmid = 2.2437, Thigh = 2.2437 | e = 0.001
#
# Critical point = 2.2431640625
#
# ======================================================
#
# Initial search:
# Thigh = 3.2431640625
# Thigh = 2.2431640625
# Tlow = 1.2431640625
#
# Tlow = 1.2432, Tmid = 1.7432, Thigh = 2.2432 | e = 1.0
# phase: not disorder!
# Tlow = 1.7432, Tmid = 1.9932, Thigh = 2.2432 | e = 0.5
# phase: not disorder!
# Tlow = 1.9932, Tmid = 2.1182, Thigh = 2.2432 | e = 0.25
# Tlow = 1.9932, Tmid = 2.0557, Thigh = 2.1182 | e = 0.125
# Tlow = 1.9932, Tmid = 2.0244, Thigh = 2.0557 | e = 0.0625
# Tlow = 1.9932, Tmid = 2.0088, Thigh = 2.0244 | e = 0.0312
# Tlow = 1.9932, Tmid = 2.001, Thigh = 2.0088 | e = 0.0156
# phase: not disorder!
# Tlow = 2.001, Tmid = 2.0049, Thigh = 2.0088 | e = 0.0078
# Tlow = 2.001, Tmid = 2.0029, Thigh = 2.0049 | e = 0.0039
# Tlow = 2.001, Tmid = 2.002, Thigh = 2.0029 | e = 0.002
# phase: not disorder!
# Tlow = 2.002, Tmid = 2.002, Thigh = 2.0029 | e = 0.001
#
# Critical point = 2.00244140625
#
# ======================================================
#
# Initial search:
# Thigh = 3.00244140625
# Tlow = 2.00244140625
#
# Tlow = 2.0024, Tmid = 2.5024, Thigh = 3.0024 | e = 1.0
# Tlow = 2.0024, Tmid = 2.2524, Thigh = 2.5024 | e = 0.5
# Tlow = 2.0024, Tmid = 2.1274, Thigh = 2.2524 | e = 0.25
# phase: not disorder!
# Tlow = 2.1274, Tmid = 2.1899, Thigh = 2.2524 | e = 0.125
# Tlow = 2.1274, Tmid = 2.1587, Thigh = 2.1899 | e = 0.0625
# Tlow = 2.1274, Tmid = 2.1431, Thigh = 2.1587 | e = 0.0312
# Tlow = 2.1274, Tmid = 2.1353, Thigh = 2.1431 | e = 0.0156
# Tlow = 2.1274, Tmid = 2.1313, Thigh = 2.1353 | e = 0.0078
# Tlow = 2.1274, Tmid = 2.1294, Thigh = 2.1313 | e = 0.0039
# Tlow = 2.1274, Tmid = 2.1284, Thigh = 2.1294 | e = 0.002
# Tlow = 2.1274, Tmid = 2.1284, Thigh = 2.1284 | e = 0.001
#
# Critical point = 2.1279296875
#
# ======================================================

# %% [markdown]
# ## Vertical phase boundaries

# %% [markdown]
# ### Calculation of the vertical phase boundary

# %%
pc = 0.1
N = 500
mp.mp.dps = 20

T_values = np.linspace(6, 0.01, 10)
ferro_boundary = []
for i, T in enumerate(T_values):

    pi = pc - 0.03
    pc = critical_point(T, pi, N, 0.001, 'horizontal', method)
    ferro_boundary.append([pc, 1-pc, T])
    print("\n======================================================\n")
# Out:
# Initial search:
# plow = 0.07
# plow = 0.17
# plow = 0.27
# phigh = 0.37
#
# plow = 0.27, pmid = 0.32, phigh = 0.37 | e = 0.1
# plow = 0.32, pmid = 0.345, phigh = 0.37 | e = 0.05
# plow = 0.345, pmid = 0.3575, phigh = 0.37 | e = 0.025
# phase: not ferro!
# plow = 0.345, pmid = 0.3512, phigh = 0.3575 | e = 0.0125
# phase: not ferro!
# plow = 0.345, pmid = 0.3481, phigh = 0.3512 | e = 0.0062
# phase: not ferro!
# plow = 0.345, pmid = 0.3466, phigh = 0.3481 | e = 0.0031
# phase: not ferro!
# plow = 0.345, pmid = 0.3458, phigh = 0.3466 | e = 0.0016
# plow = 0.3458, pmid = 0.3458, phigh = 0.3466 | e = 0.0008
#
# Critical point = 0.346171875
#
# ======================================================
#
# Initial search:
# plow = 0.316171875
# phigh = 0.41617187499999997
#
# plow = 0.3162, pmid = 0.3662, phigh = 0.4162 | e = 0.1
# phase: not ferro!
# plow = 0.3162, pmid = 0.3412, phigh = 0.3662 | e = 0.05
# plow = 0.3412, pmid = 0.3537, phigh = 0.3662 | e = 0.025
# plow = 0.3537, pmid = 0.3599, phigh = 0.3662 | e = 0.0125
# phase: not ferro!
# plow = 0.3537, pmid = 0.3568, phigh = 0.3599 | e = 0.0062
# phase: not ferro!
# plow = 0.3537, pmid = 0.3552, phigh = 0.3568 | e = 0.0031
# phase: not ferro!
# plow = 0.3537, pmid = 0.3545, phigh = 0.3552 | e = 0.0016
# phase: not ferro!
# plow = 0.3537, pmid = 0.3545, phigh = 0.3545 | e = 0.0008
#
# Critical point = 0.35406249999999995
#
# ======================================================
#
# Initial search:
# plow = 0.3240624999999999
# phigh = 0.4240624999999999
#
# plow = 0.3241, pmid = 0.3741, phigh = 0.4241 | e = 0.1
# phase: not ferro!
# plow = 0.3241, pmid = 0.3491, phigh = 0.3741 | e = 0.05
# plow = 0.3491, pmid = 0.3616, phigh = 0.3741 | e = 0.025
# plow = 0.3616, pmid = 0.3678, phigh = 0.3741 | e = 0.0125
# phase: not ferro!
# plow = 0.3616, pmid = 0.3647, phigh = 0.3678 | e = 0.0062
# phase: not ferro!
# plow = 0.3616, pmid = 0.3631, phigh = 0.3647 | e = 0.0031
# plow = 0.3631, pmid = 0.3639, phigh = 0.3647 | e = 0.0016
# plow = 0.3639, pmid = 0.3639, phigh = 0.3647 | e = 0.0008
#
# Critical point = 0.36429687499999985
#
# ======================================================
#
# Initial search:
# plow = 0.3342968749999998
# phigh = 0.4342968749999998
#
# plow = 0.3343, pmid = 0.3843, phigh = 0.4343 | e = 0.1
# phase: not ferro!
# plow = 0.3343, pmid = 0.3593, phigh = 0.3843 | e = 0.05
# plow = 0.3593, pmid = 0.3718, phigh = 0.3843 | e = 0.025
# phase: not ferro!
# plow = 0.3593, pmid = 0.3655, phigh = 0.3718 | e = 0.0125
# plow = 0.3655, pmid = 0.3687, phigh = 0.3718 | e = 0.0062
# plow = 0.3687, pmid = 0.3702, phigh = 0.3718 | e = 0.0031
# phase: not ferro!
# plow = 0.3687, pmid = 0.3695, phigh = 0.3702 | e = 0.0016
# plow = 0.3695, pmid = 0.3695, phigh = 0.3702 | e = 0.0008
#
# Critical point = 0.3698437499999998
#
# ======================================================
#
# Initial search:
# plow = 0.3398437499999998
# phigh = 0.43984374999999976
#
# plow = 0.3398, pmid = 0.3898, phigh = 0.4398 | e = 0.1
# phase: not ferro!
# plow = 0.3398, pmid = 0.3648, phigh = 0.3898 | e = 0.05
# plow = 0.3648, pmid = 0.3773, phigh = 0.3898 | e = 0.025
# phase: not ferro!
# plow = 0.3648, pmid = 0.3711, phigh = 0.3773 | e = 0.0125
# phase: not ferro!
# plow = 0.3648, pmid = 0.368, phigh = 0.3711 | e = 0.0062
# plow = 0.368, pmid = 0.3695, phigh = 0.3711 | e = 0.0031
# plow = 0.3695, pmid = 0.3703, phigh = 0.3711 | e = 0.0016
# phase: not ferro!
# plow = 0.3695, pmid = 0.3703, phigh = 0.3703 | e = 0.0008
#
# Critical point = 0.36992187499999973
#
# ======================================================
#
# Initial search:
# plow = 0.3399218749999997
# phigh = 0.4399218749999997
#
# plow = 0.3399, pmid = 0.3899, phigh = 0.4399 | e = 0.1
# phase: not ferro!
# plow = 0.3399, pmid = 0.3649, phigh = 0.3899 | e = 0.05
# plow = 0.3649, pmid = 0.3774, phigh = 0.3899 | e = 0.025
# phase: not ferro!
# plow = 0.3649, pmid = 0.3712, phigh = 0.3774 | e = 0.0125
# phase: not ferro!
# plow = 0.3649, pmid = 0.368, phigh = 0.3712 | e = 0.0062
# phase: not ferro!
# plow = 0.3649, pmid = 0.3665, phigh = 0.368 | e = 0.0031
# plow = 0.3665, pmid = 0.3673, phigh = 0.368 | e = 0.0016
# plow = 0.3673, pmid = 0.3673, phigh = 0.368 | e = 0.0008
#
# Critical point = 0.3676562499999997
#
# ======================================================
#
# Initial search:
# plow = 0.33765624999999966
# phigh = 0.43765624999999964
#
# plow = 0.3377, pmid = 0.3877, phigh = 0.4377 | e = 0.1
# phase: not ferro!
# plow = 0.3377, pmid = 0.3627, phigh = 0.3877 | e = 0.05
# phase: not ferro!
# plow = 0.3377, pmid = 0.3502, phigh = 0.3627 | e = 0.025
# plow = 0.3502, pmid = 0.3564, phigh = 0.3627 | e = 0.0125
# plow = 0.3564, pmid = 0.3595, phigh = 0.3627 | e = 0.0062
# plow = 0.3595, pmid = 0.3611, phigh = 0.3627 | e = 0.0031
# plow = 0.3611, pmid = 0.3619, phigh = 0.3627 | e = 0.0016
# plow = 0.3619, pmid = 0.3619, phigh = 0.3627 | e = 0.0008
#
# Critical point = 0.3622656249999997
#
# ======================================================
#
# Initial search:
# plow = 0.3322656249999997
# phigh = 0.43226562499999965
#
# plow = 0.3323, pmid = 0.3823, phigh = 0.4323 | e = 0.1
# phase: not ferro!
# plow = 0.3323, pmid = 0.3573, phigh = 0.3823 | e = 0.05
# phase: not ferro!
# plow = 0.3323, pmid = 0.3448, phigh = 0.3573 | e = 0.025
# plow = 0.3448, pmid = 0.351, phigh = 0.3573 | e = 0.0125
# plow = 0.351, pmid = 0.3541, phigh = 0.3573 | e = 0.0062
# plow = 0.3541, pmid = 0.3557, phigh = 0.3573 | e = 0.0031
# plow = 0.3557, pmid = 0.3565, phigh = 0.3573 | e = 0.0016
# phase: not ferro!
# plow = 0.3557, pmid = 0.3565, phigh = 0.3565 | e = 0.0008
#
# Critical point = 0.35609374999999965
#
# ======================================================
#
# Initial search:
# plow = 0.3260937499999996
# phigh = 0.4260937499999996
#
# plow = 0.3261, pmid = 0.3761, phigh = 0.4261 | e = 0.1
# phase: not ferro!
# plow = 0.3261, pmid = 0.3511, phigh = 0.3761 | e = 0.05
# plow = 0.3511, pmid = 0.3636, phigh = 0.3761 | e = 0.025
# phase: not ferro!
# plow = 0.3511, pmid = 0.3573, phigh = 0.3636 | e = 0.0125
# phase: not ferro!
# plow = 0.3511, pmid = 0.3542, phigh = 0.3573 | e = 0.0062
# plow = 0.3542, pmid = 0.3558, phigh = 0.3573 | e = 0.0031
# plow = 0.3558, pmid = 0.3566, phigh = 0.3573 | e = 0.0016
# phase: not ferro!
# plow = 0.3558, pmid = 0.3566, phigh = 0.3566 | e = 0.0008
#
# Critical point = 0.3561718749999996
#
# ======================================================
#
# Initial search:
# plow = 0.32617187499999956
# phigh = 0.42617187499999953
#
# plow = 0.3262, pmid = 0.3762, phigh = 0.4262 | e = 0.1
# phase: not ferro!
# plow = 0.3262, pmid = 0.3512, phigh = 0.3762 | e = 0.05
# plow = 0.3512, pmid = 0.3637, phigh = 0.3762 | e = 0.025
# phase: not ferro!
# plow = 0.3512, pmid = 0.3574, phigh = 0.3637 | e = 0.0125
# phase: not ferro!
# plow = 0.3512, pmid = 0.3543, phigh = 0.3574 | e = 0.0062
# phase: not ferro!
# plow = 0.3512, pmid = 0.3527, phigh = 0.3543 | e = 0.0031
# plow = 0.3527, pmid = 0.3535, phigh = 0.3543 | e = 0.0016
# plow = 0.3535, pmid = 0.3535, phigh = 0.3543 | e = 0.0008
#
# Critical point = 0.35390624999999953
#
# ======================================================

# %% [markdown]
# # Plot the phase diagram

# %%
# Transform the calculated boundaries into numpy arrays
hboundary = np.array(para_boundary)
vboundary = np.array(ferro_boundary)

# %%
plt.style.use('classic')
fig = plt.figure(figsize=(8, 6))
fig.set_facecolor('none')

lw = 2
fs = 20
plt.rc('lines', linewidth=lw)
plt.rc('axes', linewidth=lw)

ax = plt.subplot(111)
ax.plot(hboundary[:,0], hboundary[:,2], ls='-', c='k')
ax.plot(hboundary[:,1], hboundary[:,2], ls='-', c='k')
ax.plot(vboundary[:,0], vboundary[:,2], ls='-', c='k')
ax.plot(vboundary[:,1], vboundary[:,2], ls='-', c='k')

ax.axis([0, 1, 0, 30])
ax.tick_params(axis="both", direction="in", left=True,
               width=lw, length=4, labelsize=fs)
ax.set_xlabel("Antiferromagnetic Bond Concentration p", fontsize=fs)
ax.set_ylabel("Temperature $1/J$", fontsize=fs)

ax.text(0.48, 10, "D", fontsize=fs)
ax.text(0.1, 5, "F", fontsize=fs)
ax.text(0.88, 5, "AF", fontsize=fs)
ax.text(0.4, 0.2, "SG", fontsize=fs)

plt.tight_layout()
plt.show()
