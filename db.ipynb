# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import mpmath as mp
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from renormalization import *
method = 'db'

# %% [markdown]
# ## Single search for a critical point

# %%
T = 3 # The system is certainly in disordered phase for T = 3
p = 0.
N =  500
mp.mp.dps = 20 # Set the precision of mpmath to 20 decimal places
critical_point(T, p, N, 0.001, "vertical", method)
# Out:
# Initial search:
# Thigh = 3
# Tlow = 2
#
# Tlow = 2, Tmid = 2.5, Thigh = 3 | e = 1
# phase: not disorder!
# Tlow = 2.5, Tmid = 2.75, Thigh = 3 | e = 0.5
# phase: not disorder!
# Tlow = 2.75, Tmid = 2.875, Thigh = 3 | e = 0.25
# Tlow = 2.75, Tmid = 2.8125, Thigh = 2.875 | e = 0.125
# phase: not disorder!
# Tlow = 2.8125, Tmid = 2.8438, Thigh = 2.875 | e = 0.0625
# Tlow = 2.8125, Tmid = 2.8281, Thigh = 2.8438 | e = 0.0312
# Tlow = 2.8125, Tmid = 2.8203, Thigh = 2.8281 | e = 0.0156
# phase: not disorder!
# Tlow = 2.8203, Tmid = 2.8242, Thigh = 2.8281 | e = 0.0078
# Tlow = 2.8203, Tmid = 2.8223, Thigh = 2.8242 | e = 0.0039
# phase: not disorder!
# Tlow = 2.8223, Tmid = 2.8232, Thigh = 2.8242 | e = 0.002
# phase: not disorder!
# Tlow = 2.8232, Tmid = 2.8232, Thigh = 2.8242 | e = 0.001
#
# Critical point = 2.82373046875
# 2.82373046875

# %% [markdown]
# # Phase boundary by multiple searches

# %% [markdown]
# ## Horizontal phase boundary

# %% [markdown]
# ### Prepare p values to search for

# %%
# Method 1: Equally spaced p values
p_values = np.linspace(0, 0.5, 20)

# %%
# Method 2: Non-equally spaced p values (more points near the radically changing slope)
# This is done to avoid unnecessary calculations in regions where the slope is almost constant
pi = 0
p_values = [pi]    

Np = 3
for i in range(Np):
    pi = pi + 0.34 / Np
    p_values.append(round(pi, 5))
    
Np = 7
for i in range(Np):
    pi = pi + 0.1 / Np
    p_values.append(round(pi, 5))

Np = 3
for i in range(Np):
    pi = pi + 0.06 / Np
    p_values.append(round(pi, 5))

# %% [markdown]
# ### Calculation of the horizontal phase boundary

# %%
Tc = 3
N = 500
mp.mp.dps = 20

para_boundary = []
for i, p in enumerate(p_values):

    Ti = Tc + 0.2
    Tc = critical_point(Ti, p, N, 0.001, "vertical", method)
    para_boundary.append([p, 1-p, Tc])

    print("\n======================================================\n")
# Out:
# Initial search:
# Thigh = 3.2
# Tlow = 2.2
#
# Tlow = 2.2, Tmid = 2.7, Thigh = 3.2 | e = 1.0
# phase: not disorder!
# Tlow = 2.7, Tmid = 2.95, Thigh = 3.2 | e = 0.5
# Tlow = 2.7, Tmid = 2.825, Thigh = 2.95 | e = 0.25
# Tlow = 2.7, Tmid = 2.7625, Thigh = 2.825 | e = 0.125
# phase: not disorder!
# Tlow = 2.7625, Tmid = 2.7938, Thigh = 2.825 | e = 0.0625
# phase: not disorder!
# Tlow = 2.7938, Tmid = 2.8094, Thigh = 2.825 | e = 0.0312
# phase: not disorder!
# Tlow = 2.8094, Tmid = 2.8172, Thigh = 2.825 | e = 0.0156
# phase: not disorder!
# Tlow = 2.8172, Tmid = 2.8211, Thigh = 2.825 | e = 0.0078
# phase: not disorder!
# Tlow = 2.8211, Tmid = 2.823, Thigh = 2.825 | e = 0.0039
# phase: not disorder!
# Tlow = 2.823, Tmid = 2.824, Thigh = 2.825 | e = 0.002
# Tlow = 2.823, Tmid = 2.824, Thigh = 2.824 | e = 0.001
#
# Critical point = 2.82353515625
#
# ======================================================
#
# Initial search:
# Thigh = 3.0235351562500004
# Tlow = 2.0235351562500004
#
# Tlow = 2.0235, Tmid = 2.5235, Thigh = 3.0235 | e = 1.0
# phase: not disorder!
# Tlow = 2.5235, Tmid = 2.7735, Thigh = 3.0235 | e = 0.5
# Tlow = 2.5235, Tmid = 2.6485, Thigh = 2.7735 | e = 0.25
# phase: not disorder!
# Tlow = 2.6485, Tmid = 2.711, Thigh = 2.7735 | e = 0.125
# Tlow = 2.6485, Tmid = 2.6798, Thigh = 2.711 | e = 0.0625
# phase: not disorder!
# Tlow = 2.6798, Tmid = 2.6954, Thigh = 2.711 | e = 0.0312
# Tlow = 2.6798, Tmid = 2.6876, Thigh = 2.6954 | e = 0.0156
# Tlow = 2.6798, Tmid = 2.6837, Thigh = 2.6876 | e = 0.0078
# Tlow = 2.6798, Tmid = 2.6817, Thigh = 2.6837 | e = 0.0039
# Tlow = 2.6798, Tmid = 2.6808, Thigh = 2.6817 | e = 0.002
# Tlow = 2.6798, Tmid = 2.6808, Thigh = 2.6808 | e = 0.001
#
# Critical point = 2.6802734375000004
#
# ======================================================
#
# Initial search:
# Thigh = 2.8802734375000005
# Tlow = 1.8802734375000005
#
# Tlow = 1.8803, Tmid = 2.3803, Thigh = 2.8803 | e = 1.0
# phase: not disorder!
# Tlow = 2.3803, Tmid = 2.6303, Thigh = 2.8803 | e = 0.5
# Tlow = 2.3803, Tmid = 2.5053, Thigh = 2.6303 | e = 0.25
# phase: not disorder!
# Tlow = 2.5053, Tmid = 2.5678, Thigh = 2.6303 | e = 0.125
# Tlow = 2.5053, Tmid = 2.5365, Thigh = 2.5678 | e = 0.0625
# Tlow = 2.5053, Tmid = 2.5209, Thigh = 2.5365 | e = 0.0312
# Tlow = 2.5053, Tmid = 2.5131, Thigh = 2.5209 | e = 0.0156
# Tlow = 2.5053, Tmid = 2.5092, Thigh = 2.5131 | e = 0.0078
# phase: not disorder!
# Tlow = 2.5092, Tmid = 2.5111, Thigh = 2.5131 | e = 0.0039
# phase: not disorder!
# Tlow = 2.5111, Tmid = 2.5121, Thigh = 2.5131 | e = 0.002
# Tlow = 2.5111, Tmid = 2.5121, Thigh = 2.5121 | e = 0.001
#
# Critical point = 2.5116210937500005
#
# ======================================================
#
# Initial search:
# Thigh = 2.7116210937500007
# Tlow = 1.7116210937500007
#
# Tlow = 1.7116, Tmid = 2.2116, Thigh = 2.7116 | e = 1.0
# phase: not disorder!
# Tlow = 2.2116, Tmid = 2.4616, Thigh = 2.7116 | e = 0.5
# Tlow = 2.2116, Tmid = 2.3366, Thigh = 2.4616 | e = 0.25
# phase: not disorder!
# Tlow = 2.3366, Tmid = 2.3991, Thigh = 2.4616 | e = 0.125
# Tlow = 2.3366, Tmid = 2.3679, Thigh = 2.3991 | e = 0.0625
# Tlow = 2.3366, Tmid = 2.3522, Thigh = 2.3679 | e = 0.0312
# phase: not disorder!
# Tlow = 2.3522, Tmid = 2.3601, Thigh = 2.3679 | e = 0.0156
# Tlow = 2.3522, Tmid = 2.3562, Thigh = 2.3601 | e = 0.0078
# phase: not disorder!
# Tlow = 2.3562, Tmid = 2.3581, Thigh = 2.3601 | e = 0.0039
# phase: not disorder!
# Tlow = 2.3581, Tmid = 2.3591, Thigh = 2.3601 | e = 0.002
# Tlow = 2.3581, Tmid = 2.3591, Thigh = 2.3591 | e = 0.001
#
# Critical point = 2.3585937500000007
#
# ======================================================
#
# Initial search:
# Thigh = 2.558593750000001
# Tlow = 1.5585937500000009
#
# Tlow = 1.5586, Tmid = 2.0586, Thigh = 2.5586 | e = 1.0
# phase: not disorder!
# Tlow = 2.0586, Tmid = 2.3086, Thigh = 2.5586 | e = 0.5
# Tlow = 2.0586, Tmid = 2.1836, Thigh = 2.3086 | e = 0.25
# phase: not disorder!
# Tlow = 2.1836, Tmid = 2.2461, Thigh = 2.3086 | e = 0.125
# Tlow = 2.1836, Tmid = 2.2148, Thigh = 2.2461 | e = 0.0625
# Tlow = 2.1836, Tmid = 2.1992, Thigh = 2.2148 | e = 0.0312
# Tlow = 2.1836, Tmid = 2.1914, Thigh = 2.1992 | e = 0.0156
# Tlow = 2.1836, Tmid = 2.1875, Thigh = 2.1914 | e = 0.0078
# phase: not disorder!
# Tlow = 2.1875, Tmid = 2.1895, Thigh = 2.1914 | e = 0.0039
# phase: not disorder!
# Tlow = 2.1895, Tmid = 2.1904, Thigh = 2.1914 | e = 0.002
# phase: not disorder!
# Tlow = 2.1904, Tmid = 2.1904, Thigh = 2.1914 | e = 0.001
#
# Critical point = 2.190917968750001
#
# ======================================================
#
# Initial search:
# Thigh = 2.390917968750001
# Tlow = 1.390917968750001
#
# Tlow = 1.3909, Tmid = 1.8909, Thigh = 2.3909 | e = 1.0
# phase: not disorder!
# Tlow = 1.8909, Tmid = 2.1409, Thigh = 2.3909 | e = 0.5
# Tlow = 1.8909, Tmid = 2.0159, Thigh = 2.1409 | e = 0.25
# Tlow = 1.8909, Tmid = 1.9534, Thigh = 2.0159 | e = 0.125
# phase: not disorder!
# Tlow = 1.9534, Tmid = 1.9847, Thigh = 2.0159 | e = 0.0625
# phase: not disorder!
# Tlow = 1.9847, Tmid = 2.0003, Thigh = 2.0159 | e = 0.0312
# phase: not disorder!
# Tlow = 2.0003, Tmid = 2.0081, Thigh = 2.0159 | e = 0.0156
# phase: not disorder!
# Tlow = 2.0081, Tmid = 2.012, Thigh = 2.0159 | e = 0.0078
# Tlow = 2.0081, Tmid = 2.0101, Thigh = 2.012 | e = 0.0039
# Tlow = 2.0081, Tmid = 2.0091, Thigh = 2.0101 | e = 0.002
# phase: not disorder!
# Tlow = 2.0091, Tmid = 2.0091, Thigh = 2.0101 | e = 0.001
#
# Critical point = 2.009570312500001
#
# ======================================================
#
# Initial search:
# Thigh = 2.2095703125000012
# Tlow = 1.2095703125000012
#
# Tlow = 1.2096, Tmid = 1.7096, Thigh = 2.2096 | e = 1.0
# phase: not disorder!
# Tlow = 1.7096, Tmid = 1.9596, Thigh = 2.2096 | e = 0.5
# Tlow = 1.7096, Tmid = 1.8346, Thigh = 1.9596 | e = 0.25
# Tlow = 1.7096, Tmid = 1.7721, Thigh = 1.8346 | e = 0.125
# phase: not disorder!
# Tlow = 1.7721, Tmid = 1.8033, Thigh = 1.8346 | e = 0.0625
# phase: not disorder!
# Tlow = 1.8033, Tmid = 1.8189, Thigh = 1.8346 | e = 0.0312
# Tlow = 1.8033, Tmid = 1.8111, Thigh = 1.8189 | e = 0.0156
# phase: not disorder!
# Tlow = 1.8111, Tmid = 1.815, Thigh = 1.8189 | e = 0.0078
# phase: not disorder!
# Tlow = 1.815, Tmid = 1.817, Thigh = 1.8189 | e = 0.0039
# phase: not disorder!
# Tlow = 1.817, Tmid = 1.818, Thigh = 1.8189 | e = 0.002
# phase: not disorder!
# Tlow = 1.818, Tmid = 1.818, Thigh = 1.8189 | e = 0.001
#
# Critical point = 1.8184570312500012
#
# ======================================================
#
# Initial search:
# Thigh = 2.0184570312500014
# Tlow = 1.0184570312500014
#
# Tlow = 1.0185, Tmid = 1.5185, Thigh = 2.0185 | e = 1.0
# Tlow = 1.0185, Tmid = 1.2685, Thigh = 1.5185 | e = 0.5
# phase: not disorder!
# Tlow = 1.2685, Tmid = 1.3935, Thigh = 1.5185 | e = 0.25
# phase: not disorder!
# Tlow = 1.3935, Tmid = 1.456, Thigh = 1.5185 | e = 0.125
# phase: not disorder!
# Tlow = 1.456, Tmid = 1.4872, Thigh = 1.5185 | e = 0.0625
# phase: not disorder!
# Tlow = 1.4872, Tmid = 1.5028, Thigh = 1.5185 | e = 0.0312
# phase: not disorder!
# Tlow = 1.5028, Tmid = 1.5106, Thigh = 1.5185 | e = 0.0156
# Tlow = 1.5028, Tmid = 1.5067, Thigh = 1.5106 | e = 0.0078
# phase: not disorder!
# Tlow = 1.5067, Tmid = 1.5087, Thigh = 1.5106 | e = 0.0039
# phase: not disorder!
# Tlow = 1.5087, Tmid = 1.5097, Thigh = 1.5106 | e = 0.002
# Tlow = 1.5087, Tmid = 1.5097, Thigh = 1.5097 | e = 0.001
#
# Critical point = 1.5091796875000014
#
# ======================================================
#
# Initial search:
# Thigh = 1.7091796875000014
# Tlow = 0.7091796875000014
#
# Tlow = 0.7092, Tmid = 1.2092, Thigh = 1.7092 | e = 1.0
# Tlow = 0.7092, Tmid = 0.9592, Thigh = 1.2092 | e = 0.5
# phase: not disorder!
# Tlow = 0.9592, Tmid = 1.0842, Thigh = 1.2092 | e = 0.25
# phase: not disorder!
# Tlow = 1.0842, Tmid = 1.1467, Thigh = 1.2092 | e = 0.125
# Tlow = 1.0842, Tmid = 1.1154, Thigh = 1.1467 | e = 0.0625
# phase: not disorder!
# Tlow = 1.1154, Tmid = 1.1311, Thigh = 1.1467 | e = 0.0312
# phase: not disorder!
# Tlow = 1.1311, Tmid = 1.1389, Thigh = 1.1467 | e = 0.0156
# Tlow = 1.1311, Tmid = 1.135, Thigh = 1.1389 | e = 0.0078
# Tlow = 1.1311, Tmid = 1.133, Thigh = 1.135 | e = 0.0039
# phase: not disorder!
# Tlow = 1.133, Tmid = 1.134, Thigh = 1.135 | e = 0.002
# phase: not disorder!
# Tlow = 1.134, Tmid = 1.134, Thigh = 1.135 | e = 0.001
#
# Critical point = 1.1344726562500014
#
# ======================================================
#
# Initial search:
# Thigh = 1.3344726562500013
# Tlow = 0.33447265625000133
#
# Tlow = 0.3345, Tmid = 0.8345, Thigh = 1.3345 | e = 1.0
# phase: not disorder!
# Tlow = 0.8345, Tmid = 1.0845, Thigh = 1.3345 | e = 0.5
# Tlow = 0.8345, Tmid = 0.9595, Thigh = 1.0845 | e = 0.25
# phase: not disorder!
# Tlow = 0.9595, Tmid = 1.022, Thigh = 1.0845 | e = 0.125
# phase: not disorder!
# Tlow = 1.022, Tmid = 1.0532, Thigh = 1.0845 | e = 0.0625
# phase: not disorder!
# Tlow = 1.0532, Tmid = 1.0688, Thigh = 1.0845 | e = 0.0312
# Tlow = 1.0532, Tmid = 1.061, Thigh = 1.0688 | e = 0.0156
# phase: not disorder!
# Tlow = 1.061, Tmid = 1.0649, Thigh = 1.0688 | e = 0.0078
# phase: not disorder!
# Tlow = 1.0649, Tmid = 1.0669, Thigh = 1.0688 | e = 0.0039
# Tlow = 1.0649, Tmid = 1.0659, Thigh = 1.0669 | e = 0.002
# Tlow = 1.0649, Tmid = 1.0659, Thigh = 1.0659 | e = 0.001
#
# Critical point = 1.0654296875000013
#
# ======================================================
#
# Initial search:
# Thigh = 1.2654296875000013
# Tlow = 0.2654296875000013
#
# Tlow = 0.2654, Tmid = 0.7654, Thigh = 1.2654 | e = 1.0
# phase: not disorder!
# Tlow = 0.7654, Tmid = 1.0154, Thigh = 1.2654 | e = 0.5
# Tlow = 0.7654, Tmid = 0.8904, Thigh = 1.0154 | e = 0.25
# phase: not disorder!
# Tlow = 0.8904, Tmid = 0.9529, Thigh = 1.0154 | e = 0.125
# phase: not disorder!
# Tlow = 0.9529, Tmid = 0.9842, Thigh = 1.0154 | e = 0.0625
# phase: not disorder!
# Tlow = 0.9842, Tmid = 0.9998, Thigh = 1.0154 | e = 0.0312
# phase: not disorder!
# Tlow = 0.9998, Tmid = 1.0076, Thigh = 1.0154 | e = 0.0156
# Tlow = 0.9998, Tmid = 1.0037, Thigh = 1.0076 | e = 0.0078
# Tlow = 0.9998, Tmid = 1.0018, Thigh = 1.0037 | e = 0.0039
# phase: not disorder!
# Tlow = 1.0018, Tmid = 1.0027, Thigh = 1.0037 | e = 0.002
# Tlow = 1.0018, Tmid = 1.0027, Thigh = 1.0027 | e = 0.001
#
# Critical point = 1.0022460937500013
#
# ======================================================
#
# Initial search:
# Thigh = 1.2022460937500012
# Tlow = 0.20224609375000124
#
# Tlow = 0.2022, Tmid = 0.7022, Thigh = 1.2022 | e = 1.0
# phase: not disorder!
# Tlow = 0.7022, Tmid = 0.9522, Thigh = 1.2022 | e = 0.5
# phase: not disorder!
# Tlow = 0.9522, Tmid = 1.0772, Thigh = 1.2022 | e = 0.25
# Tlow = 0.9522, Tmid = 1.0147, Thigh = 1.0772 | e = 0.125
# Tlow = 0.9522, Tmid = 0.9835, Thigh = 1.0147 | e = 0.0625
# phase: not disorder!
# Tlow = 0.9835, Tmid = 0.9991, Thigh = 1.0147 | e = 0.0312
# Tlow = 0.9835, Tmid = 0.9913, Thigh = 0.9991 | e = 0.0156
# Tlow = 0.9835, Tmid = 0.9874, Thigh = 0.9913 | e = 0.0078
# Tlow = 0.9835, Tmid = 0.9854, Thigh = 0.9874 | e = 0.0039
# phase: not disorder!
# Tlow = 0.9854, Tmid = 0.9864, Thigh = 0.9874 | e = 0.002
# Tlow = 0.9854, Tmid = 0.9864, Thigh = 0.9864 | e = 0.001
#
# Critical point = 0.9859375000000012
#
# ======================================================
#
# Initial search:
# Thigh = 1.1859375000000012
# Tlow = 0.1859375000000012
#
# Tlow = 0.1859, Tmid = 0.6859, Thigh = 1.1859 | e = 1.0
# phase: not disorder!
# Tlow = 0.6859, Tmid = 0.9359, Thigh = 1.1859 | e = 0.5
# phase: not disorder!
# Tlow = 0.9359, Tmid = 1.0609, Thigh = 1.1859 | e = 0.25
# Tlow = 0.9359, Tmid = 0.9984, Thigh = 1.0609 | e = 0.125
# Tlow = 0.9359, Tmid = 0.9672, Thigh = 0.9984 | e = 0.0625
# phase: not disorder!
# Tlow = 0.9672, Tmid = 0.9828, Thigh = 0.9984 | e = 0.0312
# Tlow = 0.9672, Tmid = 0.975, Thigh = 0.9828 | e = 0.0156
# phase: not disorder!
# Tlow = 0.975, Tmid = 0.9789, Thigh = 0.9828 | e = 0.0078
# Tlow = 0.975, Tmid = 0.977, Thigh = 0.9789 | e = 0.0039
# phase: not disorder!
# Tlow = 0.977, Tmid = 0.9779, Thigh = 0.9789 | e = 0.002
# Tlow = 0.977, Tmid = 0.9779, Thigh = 0.9779 | e = 0.001
#
# Critical point = 0.9774414062500012
#
# ======================================================
#
# Initial search:
# Thigh = 1.1774414062500012
# Tlow = 0.17744140625000115
#
# Tlow = 0.1774, Tmid = 0.6774, Thigh = 1.1774 | e = 1.0
# phase: not disorder!
# Tlow = 0.6774, Tmid = 0.9274, Thigh = 1.1774 | e = 0.5
# phase: not disorder!
# Tlow = 0.9274, Tmid = 1.0524, Thigh = 1.1774 | e = 0.25
# Tlow = 0.9274, Tmid = 0.9899, Thigh = 1.0524 | e = 0.125
# phase: not disorder!
# Tlow = 0.9899, Tmid = 1.0212, Thigh = 1.0524 | e = 0.0625
# Tlow = 0.9899, Tmid = 1.0056, Thigh = 1.0212 | e = 0.0312
# phase: not disorder!
# Tlow = 1.0056, Tmid = 1.0134, Thigh = 1.0212 | e = 0.0156
# phase: not disorder!
# Tlow = 1.0134, Tmid = 1.0173, Thigh = 1.0212 | e = 0.0078
# phase: not disorder!
# Tlow = 1.0173, Tmid = 1.0192, Thigh = 1.0212 | e = 0.0039
# Tlow = 1.0173, Tmid = 1.0183, Thigh = 1.0192 | e = 0.002
# phase: not disorder!
# Tlow = 1.0183, Tmid = 1.0183, Thigh = 1.0192 | e = 0.001
#
# Critical point = 1.0187500000000012
#
# ======================================================
#
# Initial search:
# Thigh = 1.218750000000001
# Tlow = 0.2187500000000011
#
# Tlow = 0.2188, Tmid = 0.7188, Thigh = 1.2188 | e = 1.0
# phase: not disorder!
# Tlow = 0.7188, Tmid = 0.9688, Thigh = 1.2188 | e = 0.5
# phase: not disorder!
# Tlow = 0.9688, Tmid = 1.0938, Thigh = 1.2188 | e = 0.25
# Tlow = 0.9688, Tmid = 1.0313, Thigh = 1.0938 | e = 0.125
# phase: not disorder!
# Tlow = 1.0313, Tmid = 1.0625, Thigh = 1.0938 | e = 0.0625
# Tlow = 1.0313, Tmid = 1.0469, Thigh = 1.0625 | e = 0.0312
# phase: not disorder!
# Tlow = 1.0469, Tmid = 1.0547, Thigh = 1.0625 | e = 0.0156
# phase: not disorder!
# Tlow = 1.0547, Tmid = 1.0586, Thigh = 1.0625 | e = 0.0078
# Tlow = 1.0547, Tmid = 1.0566, Thigh = 1.0586 | e = 0.0039
# Tlow = 1.0547, Tmid = 1.0557, Thigh = 1.0566 | e = 0.002
# phase: not disorder!
# Tlow = 1.0557, Tmid = 1.0557, Thigh = 1.0566 | e = 0.001
#
# Critical point = 1.056152343750001
#
# ======================================================
#
# Initial search:
# Thigh = 1.256152343750001
# Tlow = 0.25615234375000107
#
# Tlow = 0.2562, Tmid = 0.7562, Thigh = 1.2562 | e = 1.0
# phase: not disorder!
# Tlow = 0.7562, Tmid = 1.0062, Thigh = 1.2562 | e = 0.5
# phase: not disorder!
# Tlow = 1.0062, Tmid = 1.1312, Thigh = 1.2562 | e = 0.25
# Tlow = 1.0062, Tmid = 1.0687, Thigh = 1.1312 | e = 0.125
# Tlow = 1.0062, Tmid = 1.0374, Thigh = 1.0687 | e = 0.0625
# Tlow = 1.0062, Tmid = 1.0218, Thigh = 1.0374 | e = 0.0312
# Tlow = 1.0062, Tmid = 1.014, Thigh = 1.0218 | e = 0.0156
# phase: not disorder!
# Tlow = 1.014, Tmid = 1.0179, Thigh = 1.0218 | e = 0.0078
# Tlow = 1.014, Tmid = 1.0159, Thigh = 1.0179 | e = 0.0039
# phase: not disorder!
# Tlow = 1.0159, Tmid = 1.0169, Thigh = 1.0179 | e = 0.002
# phase: not disorder!
# Tlow = 1.0169, Tmid = 1.0169, Thigh = 1.0179 | e = 0.001
#
# Critical point = 1.017382812500001
#
# ======================================================
#
# Initial search:
# Thigh = 1.217382812500001
# Tlow = 0.21738281250000102
#
# Tlow = 0.2174, Tmid = 0.7174, Thigh = 1.2174 | e = 1.0
# phase: not disorder!
# Tlow = 0.7174, Tmid = 0.9674, Thigh = 1.2174 | e = 0.5
# phase: not disorder!
# Tlow = 0.9674, Tmid = 1.0924, Thigh = 1.2174 | e = 0.25
# Tlow = 0.9674, Tmid = 1.0299, Thigh = 1.0924 | e = 0.125
# Tlow = 0.9674, Tmid = 0.9986, Thigh = 1.0299 | e = 0.0625
# phase: not disorder!
# Tlow = 0.9986, Tmid = 1.0143, Thigh = 1.0299 | e = 0.0312
# Tlow = 0.9986, Tmid = 1.0064, Thigh = 1.0143 | e = 0.0156
# Tlow = 0.9986, Tmid = 1.0025, Thigh = 1.0064 | e = 0.0078
# Tlow = 0.9986, Tmid = 1.0006, Thigh = 1.0025 | e = 0.0039
# Tlow = 0.9986, Tmid = 0.9996, Thigh = 1.0006 | e = 0.002
# phase: not disorder!
# Tlow = 0.9996, Tmid = 0.9996, Thigh = 1.0006 | e = 0.001
#
# Critical point = 1.000097656250001
#
# ======================================================
#
# Initial search:
# Thigh = 1.200097656250001
# Tlow = 0.20009765625000098
#
# Tlow = 0.2001, Tmid = 0.7001, Thigh = 1.2001 | e = 1.0
# phase: not disorder!
# Tlow = 0.7001, Tmid = 0.9501, Thigh = 1.2001 | e = 0.5
# phase: not disorder!
# Tlow = 0.9501, Tmid = 1.0751, Thigh = 1.2001 | e = 0.25
# Tlow = 0.9501, Tmid = 1.0126, Thigh = 1.0751 | e = 0.125
# Tlow = 0.9501, Tmid = 0.9813, Thigh = 1.0126 | e = 0.0625
# phase: not disorder!
# Tlow = 0.9813, Tmid = 0.997, Thigh = 1.0126 | e = 0.0312
# Tlow = 0.9813, Tmid = 0.9892, Thigh = 0.997 | e = 0.0156
# phase: not disorder!
# Tlow = 0.9892, Tmid = 0.9931, Thigh = 0.997 | e = 0.0078
# Tlow = 0.9892, Tmid = 0.9911, Thigh = 0.9931 | e = 0.0039
# Tlow = 0.9892, Tmid = 0.9901, Thigh = 0.9911 | e = 0.002
# phase: not disorder!
# Tlow = 0.9901, Tmid = 0.9901, Thigh = 0.9911 | e = 0.001
#
# Critical point = 0.990625000000001
#
# ======================================================
#
# Initial search:
# Thigh = 1.190625000000001
# Tlow = 0.19062500000000093
#
# Tlow = 0.1906, Tmid = 0.6906, Thigh = 1.1906 | e = 1.0
# phase: not disorder!
# Tlow = 0.6906, Tmid = 0.9406, Thigh = 1.1906 | e = 0.5
# phase: not disorder!
# Tlow = 0.9406, Tmid = 1.0656, Thigh = 1.1906 | e = 0.25
# Tlow = 0.9406, Tmid = 1.0031, Thigh = 1.0656 | e = 0.125
# phase: not disorder!
# Tlow = 1.0031, Tmid = 1.0344, Thigh = 1.0656 | e = 0.0625
# Tlow = 1.0031, Tmid = 1.0188, Thigh = 1.0344 | e = 0.0312
# Tlow = 1.0031, Tmid = 1.0109, Thigh = 1.0188 | e = 0.0156
# Tlow = 1.0031, Tmid = 1.007, Thigh = 1.0109 | e = 0.0078
# phase: not disorder!
# Tlow = 1.007, Tmid = 1.009, Thigh = 1.0109 | e = 0.0039
# phase: not disorder!
# Tlow = 1.009, Tmid = 1.01, Thigh = 1.0109 | e = 0.002
# Tlow = 1.009, Tmid = 1.01, Thigh = 1.01 | e = 0.001
#
# Critical point = 1.009472656250001
#
# ======================================================
#
# Initial search:
# Thigh = 1.2094726562500009
# Tlow = 0.2094726562500009
#
# Tlow = 0.2095, Tmid = 0.7095, Thigh = 1.2095 | e = 1.0
# phase: not disorder!
# Tlow = 0.7095, Tmid = 0.9595, Thigh = 1.2095 | e = 0.5
# phase: not disorder!
# Tlow = 0.9595, Tmid = 1.0845, Thigh = 1.2095 | e = 0.25
# Tlow = 0.9595, Tmid = 1.022, Thigh = 1.0845 | e = 0.125
# Tlow = 0.9595, Tmid = 0.9907, Thigh = 1.022 | e = 0.0625
# Tlow = 0.9595, Tmid = 0.9751, Thigh = 0.9907 | e = 0.0312
# Tlow = 0.9595, Tmid = 0.9673, Thigh = 0.9751 | e = 0.0156
# phase: not disorder!
# Tlow = 0.9673, Tmid = 0.9712, Thigh = 0.9751 | e = 0.0078
# Tlow = 0.9673, Tmid = 0.9692, Thigh = 0.9712 | e = 0.0039
# phase: not disorder!
# Tlow = 0.9692, Tmid = 0.9702, Thigh = 0.9712 | e = 0.002
# Tlow = 0.9692, Tmid = 0.9702, Thigh = 0.9702 | e = 0.001
#
# Critical point = 0.9697265625000009
#
# ======================================================

# %% [markdown]
# ## Vertical phase boundaries

# %% [markdown]
# ### Calculation of the vertical phase boundary

# %%
pc = 0.1
N = 500
mp.mp.dps = 20

T_values = np.linspace(3, 0.01, 10)
ferro_boundary = []
for i, T in enumerate(T_values):

    pi = pc - 0.03
    pc = critical_point(T, pi, N, 0.001, 'horizontal', method)
    ferro_boundary.append([pc, 1-pc, T])
    print("\n======================================================\n")
# Out:
# Initial search:
# plow = 0.07
# phigh = 0.17
#
# plow = 0.07, pmid = 0.12, phigh = 0.17 | e = 0.1
# phase: not ferro!
# plow = 0.07, pmid = 0.095, phigh = 0.12 | e = 0.05
# phase: not ferro!
# plow = 0.07, pmid = 0.0825, phigh = 0.095 | e = 0.025
# phase: not ferro!
# plow = 0.07, pmid = 0.0763, phigh = 0.0825 | e = 0.0125
# phase: not ferro!
# plow = 0.07, pmid = 0.0731, phigh = 0.0763 | e = 0.0063
# phase: not ferro!
# plow = 0.07, pmid = 0.0716, phigh = 0.0731 | e = 0.0031
# phase: not ferro!
# plow = 0.07, pmid = 0.0708, phigh = 0.0716 | e = 0.0016
# phase: not ferro!
# plow = 0.07, pmid = 0.0708, phigh = 0.0708 | e = 0.0008
#
# Critical point = 0.07039062500000001
#
# ======================================================
#
# Initial search:
# plow = 0.04039062500000001
# phigh = 0.14039062500000002
#
# plow = 0.0404, pmid = 0.0904, phigh = 0.1404 | e = 0.1
# phase: not ferro!
# plow = 0.0404, pmid = 0.0654, phigh = 0.0904 | e = 0.05
# phase: not ferro!
# plow = 0.0404, pmid = 0.0529, phigh = 0.0654 | e = 0.025
# phase: not ferro!
# plow = 0.0404, pmid = 0.0466, phigh = 0.0529 | e = 0.0125
# phase: not ferro!
# plow = 0.0404, pmid = 0.0435, phigh = 0.0466 | e = 0.0062
# phase: not ferro!
# plow = 0.0404, pmid = 0.042, phigh = 0.0435 | e = 0.0031
# phase: not ferro!
# plow = 0.0404, pmid = 0.0412, phigh = 0.042 | e = 0.0016
# phase: not ferro!
# plow = 0.0404, pmid = 0.0412, phigh = 0.0412 | e = 0.0008
#
# Critical point = 0.04078125000000001
#
# ======================================================
#
# Initial search:
# plow = 0.010781250000000013
# phigh = 0.11078125000000003
#
# plow = 0.0108, pmid = 0.0608, phigh = 0.1108 | e = 0.1
# plow = 0.0608, pmid = 0.0858, phigh = 0.1108 | e = 0.05
# phase: not ferro!
# plow = 0.0608, pmid = 0.0733, phigh = 0.0858 | e = 0.025
# plow = 0.0733, pmid = 0.0795, phigh = 0.0858 | e = 0.0125
# plow = 0.0795, pmid = 0.0827, phigh = 0.0858 | e = 0.0063
# phase: not ferro!
# plow = 0.0795, pmid = 0.0811, phigh = 0.0827 | e = 0.0031
# plow = 0.0811, pmid = 0.0819, phigh = 0.0827 | e = 0.0016
# plow = 0.0819, pmid = 0.0819, phigh = 0.0827 | e = 0.0008
#
# Critical point = 0.08226562500000004
#
# ======================================================
#
# Initial search:
# plow = 0.05226562500000004
# phigh = 0.15226562500000004
#
# plow = 0.0523, pmid = 0.1023, phigh = 0.1523 | e = 0.1
# plow = 0.1023, pmid = 0.1273, phigh = 0.1523 | e = 0.05
# plow = 0.1273, pmid = 0.1398, phigh = 0.1523 | e = 0.025
# phase: not ferro!
# plow = 0.1273, pmid = 0.1335, phigh = 0.1398 | e = 0.0125
# phase: not ferro!
# plow = 0.1273, pmid = 0.1304, phigh = 0.1335 | e = 0.0063
# plow = 0.1304, pmid = 0.132, phigh = 0.1335 | e = 0.0031
# plow = 0.132, pmid = 0.1327, phigh = 0.1335 | e = 0.0016
# phase: not ferro!
# plow = 0.132, pmid = 0.1327, phigh = 0.1327 | e = 0.0008
#
# Critical point = 0.13234375000000007
#
# ======================================================
#
# Initial search:
# plow = 0.10234375000000007
# phigh = 0.20234375000000007
#
# plow = 0.1023, pmid = 0.1523, phigh = 0.2023 | e = 0.1
# plow = 0.1523, pmid = 0.1773, phigh = 0.2023 | e = 0.05
# phase: not ferro!
# plow = 0.1523, pmid = 0.1648, phigh = 0.1773 | e = 0.025
# plow = 0.1648, pmid = 0.1711, phigh = 0.1773 | e = 0.0125
# plow = 0.1711, pmid = 0.1742, phigh = 0.1773 | e = 0.0063
# plow = 0.1742, pmid = 0.1758, phigh = 0.1773 | e = 0.0031
# plow = 0.1758, pmid = 0.1766, phigh = 0.1773 | e = 0.0016
# phase: not ferro!
# plow = 0.1758, pmid = 0.1766, phigh = 0.1766 | e = 0.0008
#
# Critical point = 0.1761718750000001
#
# ======================================================
#
# Initial search:
# plow = 0.1461718750000001
# phigh = 0.2461718750000001
#
# plow = 0.1462, pmid = 0.1962, phigh = 0.2462 | e = 0.1
# phase: not ferro!
# plow = 0.1462, pmid = 0.1712, phigh = 0.1962 | e = 0.05
# plow = 0.1712, pmid = 0.1837, phigh = 0.1962 | e = 0.025
# plow = 0.1837, pmid = 0.1899, phigh = 0.1962 | e = 0.0125
# plow = 0.1899, pmid = 0.193, phigh = 0.1962 | e = 0.0063
# phase: not ferro!
# plow = 0.1899, pmid = 0.1915, phigh = 0.193 | e = 0.0031
# phase: not ferro!
# plow = 0.1899, pmid = 0.1907, phigh = 0.1915 | e = 0.0016
# phase: not ferro!
# plow = 0.1899, pmid = 0.1907, phigh = 0.1907 | e = 0.0008
#
# Critical point = 0.1903125000000001
#
# ======================================================
#
# Initial search:
# plow = 0.1603125000000001
# phigh = 0.2603125000000001
#
# plow = 0.1603, pmid = 0.2103, phigh = 0.2603 | e = 0.1
# phase: not ferro!
# plow = 0.1603, pmid = 0.1853, phigh = 0.2103 | e = 0.05
# plow = 0.1853, pmid = 0.1978, phigh = 0.2103 | e = 0.025
# phase: not ferro!
# plow = 0.1853, pmid = 0.1916, phigh = 0.1978 | e = 0.0125
# phase: not ferro!
# plow = 0.1853, pmid = 0.1884, phigh = 0.1916 | e = 0.0063
# plow = 0.1884, pmid = 0.19, phigh = 0.1916 | e = 0.0031
# phase: not ferro!
# plow = 0.1884, pmid = 0.1892, phigh = 0.19 | e = 0.0016
# plow = 0.1892, pmid = 0.1892, phigh = 0.19 | e = 0.0008
#
# Critical point = 0.1896093750000001
#
# ======================================================
#
# Initial search:
# plow = 0.1596093750000001
# phigh = 0.25960937500000014
#
# plow = 0.1596, pmid = 0.2096, phigh = 0.2596 | e = 0.1
# phase: not ferro!
# plow = 0.1596, pmid = 0.1846, phigh = 0.2096 | e = 0.05
# plow = 0.1846, pmid = 0.1971, phigh = 0.2096 | e = 0.025
# phase: not ferro!
# plow = 0.1846, pmid = 0.1909, phigh = 0.1971 | e = 0.0125
# phase: not ferro!
# plow = 0.1846, pmid = 0.1877, phigh = 0.1909 | e = 0.0063
# plow = 0.1877, pmid = 0.1893, phigh = 0.1909 | e = 0.0031
# phase: not ferro!
# plow = 0.1877, pmid = 0.1885, phigh = 0.1893 | e = 0.0016
# phase: not ferro!
# plow = 0.1877, pmid = 0.1885, phigh = 0.1885 | e = 0.0008
#
# Critical point = 0.18812500000000013
#
# ======================================================
#
# Initial search:
# plow = 0.15812500000000013
# phigh = 0.25812500000000016
#
# plow = 0.1581, pmid = 0.2081, phigh = 0.2581 | e = 0.1
# phase: not ferro!
# plow = 0.1581, pmid = 0.1831, phigh = 0.2081 | e = 0.05
# plow = 0.1831, pmid = 0.1956, phigh = 0.2081 | e = 0.025
# phase: not ferro!
# plow = 0.1831, pmid = 0.1894, phigh = 0.1956 | e = 0.0125
# phase: not ferro!
# plow = 0.1831, pmid = 0.1863, phigh = 0.1894 | e = 0.0063
# plow = 0.1863, pmid = 0.1878, phigh = 0.1894 | e = 0.0031
# plow = 0.1878, pmid = 0.1886, phigh = 0.1894 | e = 0.0016
# phase: not ferro!
# plow = 0.1878, pmid = 0.1886, phigh = 0.1886 | e = 0.0008
#
# Critical point = 0.18820312500000017
#
# ======================================================
#
# Initial search:
# plow = 0.15820312500000017
# phigh = 0.2582031250000002
#
# plow = 0.1582, pmid = 0.2082, phigh = 0.2582 | e = 0.1
# phase: not ferro!
# plow = 0.1582, pmid = 0.1832, phigh = 0.2082 | e = 0.05
# plow = 0.1832, pmid = 0.1957, phigh = 0.2082 | e = 0.025
# phase: not ferro!
# plow = 0.1832, pmid = 0.1895, phigh = 0.1957 | e = 0.0125
# phase: not ferro!
# plow = 0.1832, pmid = 0.1863, phigh = 0.1895 | e = 0.0063
# plow = 0.1863, pmid = 0.1879, phigh = 0.1895 | e = 0.0031
# plow = 0.1879, pmid = 0.1887, phigh = 0.1895 | e = 0.0016
# phase: not ferro!
# plow = 0.1879, pmid = 0.1887, phigh = 0.1887 | e = 0.0008
#
# Critical point = 0.1882812500000002
#
# ======================================================

# %% [markdown]
# # Plot the phase diagram

# %%
# Transform the calculated boundaries into numpy arrays
hboundary = np.array(para_boundary)
vboundary = np.array(ferro_boundary)

# %%
plt.style.use('classic')
fig = plt.figure(figsize=(8, 6))
fig.set_facecolor('none')

lw = 2
fs = 20
plt.rc('lines', linewidth=lw)
plt.rc('axes', linewidth=lw)

ax = plt.subplot(111)
ax.plot(hboundary[:,0], hboundary[:,2], ls='-', c='k')
ax.plot(hboundary[:,1], hboundary[:,2], ls='-', c='k')
ax.plot(vboundary[:,0], vboundary[:,2], ls='-', c='k')
ax.plot(vboundary[:,1], vboundary[:,2], ls='-', c='k')

ax.axis([0, 1, 0, 3])
ax.tick_params(axis="both", direction="in", left=True,
               width=lw, length=4, labelsize=fs)
ax.set_xlabel("Antiferromagnetic Bond Concentration p", fontsize=fs)
ax.set_ylabel("Temperature $1/J$", fontsize=fs)

ax.text(0.48, 2, "D", fontsize=fs)
ax.text(0.07, 1, "F", fontsize=fs)
ax.text(0.9, 1, "AF", fontsize=fs)
ax.text(0.47, 0.4, "SG", fontsize=fs)

plt.tight_layout()
plt.show()
